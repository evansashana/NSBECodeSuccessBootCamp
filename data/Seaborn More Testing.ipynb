# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.distplot(tips['total_bill'])
# Out:
# /Users/ashanaevans/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.countplot(tips['day'])

# %%
sns.violinplot(x='time', y='total_bill', data=tips, hue='sex', split= True)

# %%
anscombe = sns.load_dataset('anscombe')

# %%
sns.lmplot('x','y', data= anscombe, col='dataset', col_wrap=2)

# %%
import matplotlib.pyplot as plt
facet= sns.FacetGrid(tips, col='day', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')
